# %% [markdown]
# <a href="https://colab.research.google.com/github/nedokormysh/Stepik_Karpov_ML/blob/main/Stepik_filtration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #edu1

# %%
import pandas as pd
import numpy as np

# %%
#student_performance = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')
students_performance = pd.read_csv('https://raw.githubusercontent.com/nedokormysh/Stepik_Karpov_ML/main/StudentsPerformance.csv')

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# Найдём всех, у кого gender = female.
# В loc можно подавать и булевы значения.

# %%
students_performance.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %% [markdown]
# Как получить булевы значения - . Объекты серии в pandas можно сравнивать с каким-то значением при помощи оператора ==.

# %% [markdown]
# Это тоже серия из тру и фолс.

# %%
students_performance.gender == 'female'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: gender, Length: 1000, dtype: bool

# %% [markdown]
# Вместо значений мы уже получаем булевый результат равно соответствующее значение в серии тому объекту, на равенство которому мы проверяем весь столбец, или не равно.
#
# Как теперь использовать результаты этого сравнения для фильтрации нашего dataframe?
#
# Берём выражение выше и подставляем его в качестве аргумента в метод loc().

# %%
students_performance.loc[students_performance.gender == 'female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# Можем как-то конкретизировать наш запрос и отобрать из нашего датафрейма только определённые колонки.

# %%
students_performance.loc[students_performance.gender == 'female', ['gender', 'writing score']]
# Out:
#      gender  writing score
# 0    female             74
# 1    female             88
# 2    female             93
# 5    female             78
# 6    female             92
# ..      ...            ...
# 993  female             74
# 995  female             95
# 997  female             65
# 998  female             77
# 999  female             86
#
# [518 rows x 2 columns]

# %% [markdown]
# Отберём теперь такие строки, у которых значение writing score превышает среднее значение в этом dataframe.

# %%
students_performance.loc[students_performance['writing score'] > students_performance['writing score'].mean()].head(10)
# Out:
#     gender race/ethnicity parental level of education     lunch  \
# 0   female        group B           bachelor's degree  standard
# 1   female        group C                some college  standard
# 2   female        group B             master's degree  standard
# 4     male        group C                some college  standard
# 5   female        group B          associate's degree  standard
# 6   female        group B                some college  standard
# 12  female        group B                 high school  standard
# 13    male        group A                some college  standard
# 15  female        group C            some high school  standard
# 16    male        group C                 high school  standard
#
#    test preparation course  math score  reading score  writing score
# 0                     none          72             72             74
# 1                completed          69             90             88
# ...

# %% [markdown]
# Можно нужное нам среднее значение сохранить в виде переменной и использовать её при фильтрации.

# %%
mean_writing_score = students_performance['writing score'].mean()
mean_writing_score
# Out:
# 68.054

# %%
students_performance.loc[students_performance['writing score'] > mean_writing_score]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# #test1
#
# Аналитик Ярослав захотел отфильтровать данные по комбинации условий и отобрать только те наблюдения, у которых значение по переменной writing score >  100, а значение переменной gender == female. Для этого Ярослав написал следующий запрос:
#
# students_performance[students_performance['writing score'] > 100 and students_performance.gender == 'female']

# %% [markdown]
# При работе с pandas series для логического И нужно использовать & вместо уже знакомого and
#
# Нужно указать приоритет операций, взяв условия в скобки [(condition) и (condition)]

# %% [markdown]
# В python для объединения условий используются булевы операторы or и and. Сначала предполагается, что если используем энд, то справа и слева булевы выражения.

# %%
True and False
# Out:
# False

# %% [markdown]
# Предположим, мы хотим скомбинировать 2 предыдущих примера. Как нам задать в этом случае общее условие фильтрации?
#
# Сделать вот так не получится:

# %%
students_performance.gender == 'female' and students_performance['writing score'] > mean_writing_score
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-cc52d3f58f56> in <module>()
# ----> 1 students_performance.gender == 'female' and students_performance['writing score'] > mean_writing_score
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1536     def __nonzero__(self):
#    1537         raise ValueError(
# -> 1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1540         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# Поскольку слева и справа от оператора and у нас не булевы примитивы (False или True), а серии pandas.
#
# С ними нужно работать по-другому.
#
# Преобразуем этот запрос:
#
# каждое условие возьмём в скобки - изолируем, чтобы не было проблем
# and заменим на &
# А результат запроса свяжем с переменной query.

# %%
query = (students_performance['writing score'] > mean_writing_score) & (students_performance.gender == 'female')

# %%
students_performance.loc[query].head()
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 5  female        group B          associate's degree  standard
# 6  female        group B                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 5                    none          71             83             78
# 6               completed          88             95             92

# %% [markdown]
# Доп. вопрос: запрос с квадратными скобками, а не круглыми:
#
# [students_performance.gender == 'female'] and [students_performance['writing score'] > mean_writing_score]
# даёт вектор из True и False, но этот вектор отличается от вектора, получаемого при запросе:
#
# (students_performance.gender == 'female') & (students_performance['writing score'] > mean_writing_score)
# Почему так происходит?
#
# Ответ:
#
# Это:
#
# (students_performance.gender == 'female') & (students_performance['writing score'] > mean_writing_score)
# пандасовская векторизированная операция - все действия (сравнения, логическое и) выполняются поэлементно.
#
# А с квадратными скобками вместо круглых, получается встроенный тип данных с python - список
#
# [students_performance.gender == 'female'] # this is a list with pd.Series
# Оператор and в питоне работает следующим образом - если 1-ый операнд True, то он возвращает 2-ой, в противном случае возвращается первый.

# %% [markdown]
# #edu2

# %%
[students_performance.gender == 'female'] and [students_performance['writing score'] > mean_writing_score]
# Out:
# [0       True
#  1       True
#  2       True
#  3      False
#  4       True
#         ...
#  995     True
#  996    False
#  997    False
#  998     True
#  999     True
#  Name: writing score, Length: 1000, dtype: bool]

# %%
(students_performance.gender == 'female') & (students_performance['writing score'] > mean_writing_score)
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998     True
# 999     True
# Length: 1000, dtype: bool

# %%
3 and 5
# Out:
# 5

# %%
0 and 3
# Out:
# 0

# %% [markdown]
# У списков булевы значения такие:
#
# [] => False
# [что-нибудь] => True
# Таким образом, мы просто получаем 2-ой список

# %% [markdown]
# #test2

# %% [markdown]
# ##1
#
# У какой доли студентов из датасэта в колонке lunch указано free/reduced?

# %%
students_performance['lunch'] == 'free/reduced'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 995    False
# 996     True
# 997     True
# 998    False
# 999     True
# Name: lunch, Length: 1000, dtype: bool

# %%
students_performance[students_performance['lunch'] == 'free/reduced'].head()
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 17  female        group B            some high school  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 3                     none          47             57             44
# 7                     none          40             43             39
# 8                completed          64             64             67
# 9                     none          38             60             50
# 17                    none          18             32             28

# %%
len(students_performance[students_performance['lunch'] == 'free/reduced'])/len(students_performance)
# Out:
# 0.355

# %%
(students_performance['lunch'] == 'free/reduced').mean()
# Out:
# 0.355

# %% [markdown]
# value_counts по умолчанию выдает количество значений в series. Если передать параметр normalize=True, то он выдаст доли (что нам и нужно).

# %%
students_performance['lunch'].value_counts(normalize=True)
# Out:
# standard        0.645
# free/reduced    0.355
# Name: lunch, dtype: float64

# %%
(students_performance['lunch'] == 'free/reduced').value_counts()
# Out:
# False    645
# True     355
# Name: lunch, dtype: int64

# %% [markdown]
# ##2
#
# Как различается среднее и дисперсия оценок по предметам у групп студентов со стандартным или урезанным ланчем?

# %% [markdown]
# студенты со стандартным ланчем имеют в среднем более хорошие оценки
#
# студенты с урезанным ланчем имеют в среднем более хорошие оценки

# %%
students_performance['math score'].describe()
# Out:
# count    1000.00000
# mean       66.08900
# std        15.16308
# min         0.00000
# 25%        57.00000
# 50%        66.00000
# 75%        77.00000
# max       100.00000
# Name: math score, dtype: float64

# %%
students_performance[['lunch', 'math score']]
# Out:
#             lunch  math score
# 0        standard          72
# 1        standard          69
# 2        standard          90
# 3    free/reduced          47
# 4        standard          76
# ..            ...         ...
# 995      standard          88
# 996  free/reduced          62
# 997  free/reduced          59
# 998      standard          68
# 999  free/reduced          77
#
# [1000 rows x 2 columns]

# %%
students_performance.loc[students_performance.lunch == 'standard', ['lunch', 'math score', 'reading score']]
# Out:
#         lunch  math score  reading score
# 0    standard          72             72
# 1    standard          69             90
# 2    standard          90             95
# 4    standard          76             78
# 5    standard          71             83
# ..        ...         ...            ...
# 987  standard          81             75
# 991  standard          65             82
# 994  standard          63             63
# 995  standard          88             99
# 998  standard          68             78
#
# [645 rows x 3 columns]

# %%
students_performance.loc[students_performance.lunch == 'standard', ['lunch', 'math score', 'reading score', 'writing score']].describe()
# Out:
#        math score  reading score  writing score
# count  645.000000     645.000000     645.000000
# mean    70.034109      71.654264      70.823256
# std     13.653501      13.830602      14.339487
# min     19.000000      26.000000      22.000000
# 25%     61.000000      63.000000      62.000000
# 50%     69.000000      72.000000      72.000000
# 75%     80.000000      82.000000      81.000000
# max    100.000000     100.000000     100.000000

# %%
students_performance.loc[students_performance.lunch == 'free/reduced', ['lunch', 'math score', 'reading score', 'writing score']].describe()
# Out:
#        math score  reading score  writing score
# count  355.000000     355.000000     355.000000
# mean    58.921127      64.653521      63.022535
# std     15.159956      14.895339      15.433823
# min      0.000000      17.000000      10.000000
# 25%     49.000000      56.000000      53.000000
# 50%     60.000000      65.000000      64.000000
# 75%     69.000000      75.000000      74.000000
# max    100.000000     100.000000     100.000000

# %%
students_performance.groupby('lunch').mean()
# Out:
#               math score  reading score  writing score
# lunch
# free/reduced   58.921127      64.653521      63.022535
# standard       70.034109      71.654264      70.823256

# %%
students_performance.groupby('lunch').var()
# Out:
#               math score  reading score  writing score
# lunch
# free/reduced  229.824270     221.871139     238.202881
# standard      186.418089     191.285560     205.620887

# %%
students_performance.groupby('lunch').describe().T
# Out:
# lunch                free/reduced    standard
# math score    count    355.000000  645.000000
#               mean      58.921127   70.034109
#               std       15.159956   13.653501
#               min        0.000000   19.000000
#               25%       49.000000   61.000000
#               50%       60.000000   69.000000
#               75%       69.000000   80.000000
#               max      100.000000  100.000000
# reading score count    355.000000  645.000000
#               mean      64.653521   71.654264
#               std       14.895339   13.830602
#               min       17.000000   26.000000
#               25%       56.000000   63.000000
#               50%       65.000000   72.000000
#               75%       75.000000   82.000000
#               max      100.000000  100.000000
# writing score count    355.000000  645.000000
#               mean      63.022535   70.823256
#               std       15.433823   14.339487
# ...

# %%
students_performance.groupby('lunch').agg(['mean', 'var'])
# Out:
#              math score             reading score             writing score  \
#                    mean         var          mean         var          mean
# lunch
# free/reduced  58.921127  229.824270     64.653521  221.871139     63.022535
# standard      70.034109  186.418089     71.654264  191.285560     70.823256
#
#
#                      var
# lunch
# free/reduced  238.202881
# standard      205.620887

# %% [markdown]
# #edu3

# %% [markdown]
# Есть специальный метод query, также позволяющий нам фильтровать dataframe.
#
# Но сначала давайте переименуем в нашем dataframe все колонки, содержащие символ пробела в своём имени.
#
# Для этого выведем названия всех столбцов нашего dataframe и выберем названия с пробелами.

# %%
#students_performance = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')
students_performance = pd.read_csv('https://raw.githubusercontent.com/nedokormysh/Stepik_Karpov_ML/main/StudentsPerformance.csv')
students_performance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_performance = students_performance\
    .rename(columns={'parental level of education': 'parental_level_of_education',
                     'test preparation course': 'test_preparation_course',
                     'math score': 'math_score',
                     'reading score': 'reading_score',
                     'writing score': 'writing_score'})

students_performance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# Метод query принимает строковый аргумент - запрос, по которому мы хотим получить нужные данные.

# %%
students_performance.query("writing_score > 75").head()
# Out:
#     gender race/ethnicity parental_level_of_education     lunch  \
# 1   female        group C                some college  standard
# 2   female        group B             master's degree  standard
# 5   female        group B          associate's degree  standard
# 6   female        group B                some college  standard
# 15  female        group C            some high school  standard
#
#    test_preparation_course  math_score  reading_score  writing_score
# 1                completed          69             90             88
# 2                     none          90             95             93
# 5                     none          71             83             78
# 6                completed          88             95             92
# 15                    none          69             75             78

# %% [markdown]
# Внутри нашего query можно без проблем проводить сравнения со строкой

# %%
students_performance.query("gender == 'female'").head()
# Out:
#    gender race/ethnicity parental_level_of_education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 5  female        group B          associate's degree  standard
# 6  female        group B                some college  standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 5                    none          71             83             78
# 6               completed          88             95             92

# %% [markdown]
# В query мы можем комбинировать наши запросы фильтрации

# %%
students_performance.query('gender == "female" & math_score > 75').head()
# Out:
#     gender race/ethnicity parental_level_of_education         lunch  \
# 2   female        group B             master's degree      standard
# 6   female        group B                some college      standard
# 56  female        group E          associate's degree      standard
# 86  female        group C                some college  free/reduced
# 94  female        group B                some college      standard
#
#    test_preparation_course  math_score  reading_score  writing_score
# 2                     none          90             95             93
# 6                completed          88             95             92
# 56               completed          82             85             86
# 86                    none          76             83             88
# 94                    none          79             86             92

# %% [markdown]
# Внутри query можно проводить сравнения с переменными, используя экранирование при помощи @

# %%
writing_score_query = 78

# %%
students_performance.query(" (writing_score > @writing_score_query) & (gender == 'female') ").head()
# Out:
#     gender race/ethnicity parental_level_of_education         lunch  \
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 6   female        group B                some college      standard
# 36  female        group D          associate's degree      standard
# 38  female        group D          associate's degree  free/reduced
#
#    test_preparation_course  math_score  reading_score  writing_score
# 1                completed          69             90             88
# 2                     none          90             95             93
# 6                completed          88             95             92
# 36                    none          74             81             83
# 38               completed          75             90             88

# %% [markdown]
# #test3

# %% [markdown]
# Соотнесите строчку кода и результат её выполнения. Переменная student_stats содержит датафрэйм с данными о студентах.
#
#
#
# Чтобы было удобно, сойдёмся на одинаковых терминах
#
# parental level of education - уровень образования родителей
# bachelor's degree - бакалаврская степень
# master's degree - магистерская степень
# test preparation course - тест
# наблюдения, студенты, строки - одно и то же в данном случае

# %% [markdown]
# student_stats[student_stats['parental level of education'].isin(["bachelor's degree", "master's degree"])] отберёт студентов, уровень образования родителей которых бакалавр или магистр
#
#
# student_stats[(student_stats['math score'] > 90) & (student_stats['reading score'] <=72)] наблюдения, оценка за математику которых выше 90 и за чтение меньше либо равна 72
#
#
# student_stats[student_stats['test preparation course'] != 'completed'] студенты, не прошедшие тест
#
#
# student_stats.query("lunch == 'standard'") студенты со стандартным ланчем

# %%
students_performance.loc[students_performance['parental_level_of_education'].isin(["bachelor's degree", "master's degree"])]
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 14   female        group A             master's degree      standard
# 18     male        group C             master's degree  free/reduced
# 24     male        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 957  female        group D             master's degree      standard
# 969  female        group B           bachelor's degree      standard
# 970  female        group D           bachelor's degree      standard
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
students_performance[students_performance['parental_level_of_education'].isin(["bachelor's degree", "master's degree"])]
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 14   female        group A             master's degree      standard
# 18     male        group C             master's degree  free/reduced
# 24     male        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 957  female        group D             master's degree      standard
# 969  female        group B           bachelor's degree      standard
# 970  female        group D           bachelor's degree      standard
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
students_performance[(students_performance['math_score'] > 78) & (students_performance['reading_score'] <= 72)].head()
# Out:
#     gender race/ethnicity parental_level_of_education     lunch  \
# 100   male        group B                some college  standard
# 206   male        group E           bachelor's degree  standard
# 317   male        group C          associate's degree  standard
# 477   male        group D          associate's degree  standard
# 538   male        group E           bachelor's degree  standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 100                    none          79             67             67
# 206                    none          82             62             62
# 317                    none          83             72             78
# 477                    none          80             68             72
# 538               completed          85             66             71

# %%
students_performance[students_performance['test_preparation_course'] != 'completed'].head()
# Out:
#    gender race/ethnicity  ... reading_score writing_score
# 0  female        group B  ...            72            74
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
# 5  female        group B  ...            83            78
#
# [5 rows x 8 columns]

# %%
students_performance.query("lunch == 'standard'").head()
# Out:
#    gender race/ethnicity  ... reading_score writing_score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 4    male        group C  ...            78            75
# 5  female        group B  ...            83            78
#
# [5 rows x 8 columns]

# %% [markdown]
# #edu4

# %% [markdown]
# В примерах выше мы фильтровали все строки нашего исходного dataframe по каким-то условиям. То есть отбирали только некоторые из полного числа строк.
#
# А что если нам нужно отобрать все строки, но нужны нам не все столбцы а только часть с определённым словом в имени.
#
# Как это сделать?
#
# Предположим, в нашем dataframe есть не 3, а гораздо больше столбцов с оценками по разным предметам. И в каждом из этих столбцов в названии есть слово score. И мы бы хотели отобрать только те колонки, где есть скор в названии
#
# Непандасовский способ.
#
# Можно заметить, что мы можем указать имена напрямую.

# %%
students_performance[['math_score', 'reading_score']].head()
# Out:
#    math_score  reading_score
# 0          72             72
# 1          69             90
# 2          90             95
# 3          47             57
# 4          76             78

# %% [markdown]
# Это наводит на мысль, что если мы сформирумем вайтлист имен, который мы хотим использовать для отбора нужных нам колонок, то мы решим нашу задачу.

# %% [markdown]
# Имена колонок

# %%
list(students_performance)
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental_level_of_education',
#  'lunch',
#  'test_preparation_course',
#  'math_score',
#  'reading_score',
#  'writing_score']

# %% [markdown]
# Или так

# %%
students_performance.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %% [markdown]
# Отберём нужные нам названия столбцов

# %%
score_columns = [i for i in list(students_performance) if 'score' in i]
score_columns
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
students_performance[score_columns].head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %% [markdown]
# Пандасовый способ. У пандаса есть метод фильтр.

# %%
students_performance.filter(like='score').head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %% [markdown]
# Это было применение фильтра для колонок, но можно и для строчек, используя индексы.

# %%
students_performance_with_names = students_performance.iloc[[0, 3, 5, 6, 12]]
students_performance_with_names.index = ['Cersei', 'Gregor', 'Arya', 'Deyneris', 'Noone']
students_performance_with_names
# Out:
#           gender race/ethnicity parental level of education         lunch  \
# Cersei    female        group B           bachelor's degree      standard
# Gregor      male        group A          associate's degree  free/reduced
# Arya      female        group B          associate's degree      standard
# Deyneris  female        group B                some college      standard
# Noone     female        group B                 high school      standard
#
#          test preparation course  math score  reading score  writing score
# Cersei                      none          72             72             74
# Gregor                      none          47             57             44
# Arya                        none          71             83             78
# Deyneris               completed          88             95             92
# Noone                       none          65             81             73

# %% [markdown]
# axis - аргумент будем ли мы применять наше условие по столбцами или строкам. = 1 - столбцы, = 0 - по строкам.

# %%
students_performance_with_names.filter(like='e', axis=0).head()
# Out:
#           gender race/ethnicity parental level of education         lunch  \
# Cersei    female        group B           bachelor's degree      standard
# Gregor      male        group A          associate's degree  free/reduced
# Deyneris  female        group B                some college      standard
# Noone     female        group B                 high school      standard
#
#          test preparation course  math score  reading score  writing score
# Cersei                      none          72             72             74
# Gregor                      none          47             57             44
# Deyneris               completed          88             95             92
# Noone                       none          65             81             73

# %%
students_performance.filter(like='8', axis=0).head()
# Out:
#     gender race/ethnicity parental_level_of_education         lunch  \
# 8     male        group D                 high school  free/reduced
# 18    male        group C             master's degree  free/reduced
# 28    male        group C                 high school      standard
# 38  female        group D          associate's degree  free/reduced
# 48  female        group D          associate's degree  free/reduced
#
#    test_preparation_course  math_score  reading_score  writing_score
# 8                completed          64             64             67
# 18               completed          46             42             46
# 28                    none          70             70             65
# 38               completed          75             90             88
# 48               completed          57             74             76

# %% [markdown]
# #test4

# %% [markdown]
# ##1

# %% [markdown]
# Изучите документацию метода filter и укажите правильные утверждения
#
# Также есть ещё похожий метод select_dtypes, отбирающий по типам колонок.
#
# Выберите все подходящие ответы из списка

# %% [markdown]
# Аргумент axis отвечает за то, какие лэйблы мы рассматриваем - индекс или колонки
#
# Можно использовать только один из аргументов items, like, regex
#
# Аргумент like отбирает те лэйблы, где встречается поданное значение
#
# Аргумент regex отбирает лэйблы, подходящие к переданному паттерну
#
# Аргумент items отбирает лэйблы, переданные в коллекции в качестве значения

# %% [markdown]
# Очень полезный метод для больших датафрэймов.
# Для применения regex, ознакомьтесь с регулярными выражениями в питоне (библиотека re), в regex можно указывать как паттерн в виде строки, так и скомпилированный в re паттерн.
# axis можно указывать как 0, 1 или как 'index', 'columns' соответственно

# %% [markdown]
# ##2
# Важной частью нашего курса будут задачи на программирование. Давайте попробуем решить первую задачу вместе.
#
# В переменной df  сохранен датафрэйм с произвольным числом колонок и строк. Отберите колонки, в которых есть '-' в датафрэйме df (вот соответствующий датасэт column_hell). Сохраните их в переменную selected_columns
#
# Если в условии задачи сообщается, что в некой переменной уже сохранен датафрэйм или другой объект, не нужно пересоздавать его самостоятельно, сразу начинайте работать с этой переменной.
#
# В нашем случае для отбора колонок соответствующих условию мы могли бы написать следующий код:
#
# selected_columns = df.filter(like='-')
# Засабмитим решение и убедимся, что оно правильное:

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nedokormysh/Stepik_Karpov_ML/main/column_hell.csv')
df.head(5)
# Out:
#       yrh&6      ohku         q      hfxx   umeca-4       apj         g  \
# 0  0.288397  0.911359  0.488069  0.074599  0.016124  0.090555  0.560810
# 1  0.861276  0.134987  0.701885  0.897921  0.507115  0.740151  0.963179
# 2  0.775577  0.832874  0.862665  0.831049  0.003274  0.703112  0.509795
# 3  0.857910  0.555818  0.598305  0.473988  0.784139  0.427963  0.725103
# 4  0.748652  0.451725  0.252619  0.584361  0.011265  0.051115  0.755444
#
#    ijvnixxo  kudbpyw-3    upubjv  ...        fi   clsruyy       g&6      qo$6  \
# 0  0.110975   0.430787  0.548763  ...  0.793122  0.070335  0.145115  0.686579
# 1  0.712024   0.671662  0.497596  ...  0.477181  0.767931  0.996055  0.948774
# 2  0.573296   0.286411  0.282792  ...  0.421542  0.770413  0.749468  0.395022
# 3  0.286610   0.863717  0.545562  ...  0.240252  0.010355  0.759912  0.965837
# 4  0.627191   0.206172  0.955043  ...  0.846165  0.043458  0.209347  0.028276
#
#          ap         o  sladymzr       tif   wuikzxt     wzuvc
# ...

# %%
selected_columns = df.filter(like='-')
selected_columns.head(5)
# Out:
#     umeca-4  kudbpyw-3       g-3       v-9     fla-6  hwtbyrkp-5
# 0  0.016124   0.430787  0.202407  0.725508  0.305076    0.979296
# 1  0.507115   0.671662  0.864249  0.867818  0.358859    0.160520
# 2  0.003274   0.286411  0.928865  0.719159  0.340235    0.734612
# 3  0.784139   0.863717  0.175446  0.554744  0.049325    0.621132
# 4  0.011265   0.206172  0.044151  0.163643  0.048806    0.437836
